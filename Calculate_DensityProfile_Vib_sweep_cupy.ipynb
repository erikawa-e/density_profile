# %% [markdown]
# # Set Up
# ## Import

# %%
import cupy as cp
import numpy as np
from numba import jit, prange, njit, vectorize
import pandas
import matplotlib.pyplot as plt
import scipy
from scipy import interpolate as itp
import itertools as it
import warnings as w
import os 
import pylab
import math
import time

# %% [markdown]
# ## Settings

# %%
#CAUTION: if R is chosen too small and N too high, then when the program will try to calculate the inverse of dGr
# in the calculation of the saturated density profile, the following error will show: 'Matrix singular to numerical precision.'
# for example, for R=0.75, N=1000 is too high.  
R=0.75#cm
H=0.2 #cm
N=500
M=200
position_of_electrons=100

hr=R/N
hz=H/M

e=4.80324e-10

N_Vib=cp.round(0.4/hr)
N_Vmb=cp.round(0.57/hr)
N_Vob = cp.round(0.7/hr)

N_Vit=N_Vib
N_Vmt=N_Vmb
N_Vot = N_Vob

x=np.linspace(0,R,N+1)

eps=1e-10
header = "R"+str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(eps))

# %% [markdown]
# # Define Functions

# %%
iRange = cp.arange(2, N+1)

@njit(parallel=True, fastmath=True)
def copyAr2D(dst, src):
    for i in prange(src.shape[0]):
        for j in range(src.shape[1]):
            dst[i, j] = src[i, j]


fitilStart = cp.full((M+1,N+1),-1/300)
fitil = cp.full((M+1,N+1),-1/300)
aStart = cp.zeros((M-1, N+1))
a = cp.zeros((M-1, N+1))

def fitilSOLUT(R,H,N,M,Vib,Vmb,Vob,N_Vib,N_Vmb,Vit,Vmt,Vot,N_Vit,N_Vmt, N_Vot, N_Vob, Vr):
    
    
    cp.copyto(fitil, fitilStart)


    # --------------- boundary conditions on the electrodes ----------------- #
    fitil[0, 0:int(N_Vib)] = Vib
    fitil[0, int(N_Vib):int(N_Vmb)] = Vmb
    fitil[0, int(N_Vmb):int(N_Vob)] = Vob
    fitil[0, int(N_Vob):] = Vr
        
    fitil[M, 0:int(N_Vit)] = Vit
    fitil[M, int(N_Vit):int(N_Vmt)] = Vmt
    fitil[M, int(N_Vmt):int(N_Vot)] = Vot
    fitil[M, int(N_Vot):] = Vr
    
      
    
    fitil[:, N] = Vr
    
    
    # ---------------- relaxation for homogenious solution ------------------ #
    max_err= 1
    #err = np.zeros((M+1, N+1))
    
    count = 0
    errHere = 1e-10
    print(count)
    cp.copyto(a, aStart)
    while (max_err > errHere):

        count += 1
        if(count % 10000 == 0):
            print(max_err)

        cp.copyto(a, fitil[1:M, 0:N+1])
        fitil[1:M, 0] = (4 * (hz/hr) * fitil[1:M, 1] + (hr/hz) * fitil[0:M-1, 0] + (hr/hz) * fitil[2:M+1, 0])/(4 * hz/hr + 2 * hr/hz)



        fitil[1:M, 1:N] = ((iRange - 1/2 - 1) * (hz/hr) * fitil[1:M, 0:N-1] + (iRange + 1/2 - 1) * (hz/hr) * fitil[1:M, 2:N+1] + (iRange-1) * (hr/hz) * fitil[0:M-1, 1:N] + (iRange-1) * (hr/hz) * fitil[2:M+1, 1:N])/(2 * (iRange-1) * (hz/hr + hr/hz))
       
        max_err = np.amax(cp.abs(fitil[1:M, 0:N+1] - a))


    return fitil

# %%
preCalcDisStat = np.arange(1, N+1)


@jit(nopython = True, fastmath=True, parallel=True)
def distribSTATIC(R,H,N,M,G,Ertil,dGr,radius_of_electron_pool):

    dens = np.zeros(N+1)
    dens[:int(radius_of_electron_pool)+1] = np.dot(Ertil[:int(radius_of_electron_pool)+1], np.linalg.inv(dGr[:int(radius_of_electron_pool)+1, :int(radius_of_electron_pool)+1]))

    A = np.zeros(N+1)

    A[0] = np.pi * np.power((hr/2), 2)
    A[N] = np.pi *(N - 5/4) * np.power(hr, 2)
    A[0:N] = 2 * np.pi * (preCalcDisStat - 1) * np.power(hr, 2)
    
    temp = A[0:len(dens)] * dens[0:len(dens)]
    
    N_total = np.sum(temp)
    
    return dens, N_total, A, temp

# %% [markdown]
# # Calculations
#
# ## Load Green Function

# %%
# # ------------ Load Green Function  ------------ #
GreenFuncName = 'Green_R' + str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(eps)) + '.npy'
G = np.load("GreenFunctions/good_versions//"+GreenFuncName)

plt.plot(G[position_of_electrons,0,:])
plt.title('Green function at the position of electrons')
plt.show()
#G = np.transpose(Gin, axes = (0, 2, 1))

# %%
dGr = np.zeros((N, N))
dGzTOP = np.zeros((N, N))
dGzBOTTOM = np.zeros((N, N))

# # ----------- Green function difference along the charge pool ----------- #
for n in range(0, N):
    for i in range(0, N):
        dGr[n,i] = -4*np.pi*e*(G[position_of_electrons,i+1,n]-G[position_of_electrons,i,n])
    
# # ----------- Green function difference across the cell's top ----------- #
        dGzTOP[n, i] = -4 * np.pi * e * (G[M, i, n] - G[M-1, i, n])*(hr/hz) #for testing
        

# # ----------- Green function difference across the cell's bottom ----------- #
        dGzBOTTOM[n,i] = -4 * np.pi * e * (G[1,i,n]-G[0,i,n])*(hr/hz)

# %% [markdown]
# ## Choose the voltage sweep

# %%
Eztil = np.zeros(N+1)

Phitil = np.zeros(N+1)
Ertil = np.zeros(N)
EztilTOP = np.zeros(N+1)
EztilBOTTOM = np.zeros(N+1)

Vit=0/300 #statvolt
Vmt=0/300 #statvolt
Vot=0/300 #statvolt

Vr=0/300 #statvolt

Vob=-20/300
Vmb=-20/300
Vib_start=3
Vib_stop=30
Vib_step=0.2
Vib = cp.arange(Vib_start, Vib_stop, Vib_step)/300
print(len(Vib))
# Out:
# 135

# %% [markdown]
# ## Calculate $\tilde \Phi$ (if it is already calculated, do not run this code)

# %%
def phitilGen():


    phitilInitial = fitilSOLUT(R,H,N,M,Vib[0],Vmb,Vob,N_Vib,N_Vmb,Vit,Vmt,Vot,N_Vit,N_Vmt, N_Vot, N_Vob, Vr)
    phitilList = cp.array(np.zeros((len(Vib), np.shape(phitilInitial)[0], np.shape(phitilInitial)[1])))
  
    phitilList[0] = phitilInitial
    

    for i in range(1,len(Vib)):
        print(len(Vib) - i)
        print('Vib ='+str(Vib[i]*300))
        phitilList[i] = fitilSOLUT(R,H,N,M,Vib[i],Vmb,Vob,N_Vib,N_Vmb,Vit,Vmt,Vot,N_Vit,N_Vmt, N_Vot, N_Vob, Vr)

    return phitilList

for Vmb in [-15/300, -20/300, -30/300]:
    Vob=Vmb
    phitilList = phitilGen()
    PhiTilName = 'Phi_R' + str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(1e-8)) + '_Vib_step='+ str(Vib_step).replace('.','pt')+ '_Vib_start=' +str(Vib_start).replace('.','pt') +'_Vib_stop='+ str(Vib_stop).replace('.','pt') +  '_Vmb'+ str(int(Vmb*300))+ '_Vob'+ str(int(Vob*300)) +'.npy'
    fileName = "phiFiles/Vib_sweep/" + str(PhiTilName)
    phitilNump = cp.asnumpy(phitilList)
    np.save(fileName, phitilNump)
# Out:
# 0
# 9.5668133926613e-07
# 3.1285822418847253e-07
# 1.0997637159629314e-07
# 3.9460595173401725e-08
# 1.4395525944899124e-08
# 5.325930637484211e-09
# 1.994417797579473e-09
# 7.550409186762863e-10
# 2.887658098749135e-10
# 1.115209764812608e-10
# 134
# Vib =3.2000000000000006
# 0
# 9.56130123248855e-07
# 3.122232581052875e-07
# 1.0957630666025286e-07
# 3.924428867638219e-08
# 1.42896544146065e-08
# 5.275588649961138e-09
# 1.9712760000734075e-09
# 7.446208337424931e-10
# 2.841201579562025e-10
# 1.0946548528734112e-10
# 133
# Vib =3.4
# 0
# 9.555789072489274e-07
# 3.115941818801482e-07
# 1.091814814876968e-07
# 3.903127206508761e-08
# 1.4183961612873608e-08
# 5.225808119568853e-09
# 1.9484126256852363e-09
# 7.342898337980852e-10
# 2.79523786061997e-10
# 1.0743429756931988e-10
# 132
# Vib =3.6
# 0
# 9.550276912524691e-07
# 3.1098700045348315e-07
# 1.0878665631861018e-07
# 3.882042103400818e-08
# 1.4079339829414783e-08
# 5.176396093015123e-09
# 1.925769422400636e-09
# 7.240870368574459e-10
# 2.7497562907208284e-10
# 1.0542709760752444e-10
# 131
# Vib =3.8
# 0
# 9.544764752351942e-07
# 3.1037981900947087e-07
# 1.0839183113217632e-07
# 3.8609569999459303e-08
# 1.3975898990187252e-08
# 5.127510145641612e-09
# 1.903284644472203e-09
# 7.139958867197205e-10
# 2.7047934031410037e-10
# 1.0344355580449438e-10
# 130
# Vib =4.0
# 0
# 9.539252592352665e-07
# 3.097726375793364e-07
# 1.0800313389805472e-07
# 3.8401282018846183e-08
# 1.3872458182184744e-08
# 5.0790196839956e-09
# 1.881124794128608e-09
# 7.039865877744855e-10
# 2.66040956625746e-10
# 1.014833390933223e-10
# 129
# Vib =4.2
# 0
# 9.533740432283999e-07
# 3.091654561492019e-07
# 1.0762090789720458e-07
# 3.8195801788792894e-08
# 1.3771162186287933e-08
# 5.0309808680149e-09
# 1.8590598435674899e-09
# 6.940909270947149e-10
# 2.6164849800669465e-10
# 128
# Vib =4.4
# 0
# 9.528428109514819e-07
# 3.085582747190674e-07
# 1.0723868186859886e-07
# 3.799032155527016e-08
# 1.3669946768296581e-08
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 20
#      18 Vob=Vmb
#      19 phitilList = phitilGen()
# ---> 20 PhiTilName = 'Phi_R' + str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(1e-8)) + '_Vmb_step='+ str(Vmb_step).replace('.','pt')+ '_Vmb_start=' +str(Vmb_start).replace('.','pt') +'_Vmb_stop='+ str(Vmb_stop).replace('.','pt') +  '_Vib'+ str(int(Vib*300))+ '_Vob'+ str(int(Vob*300)) +'.npy'
#      21 fileName = "phiFiles/Vib_sweep/" + str(PhiTilName)
#      22 phitilNump = cp.asnumpy(phitilList)
#
# NameError: name 'Vmb_step' is not defined

# %% [markdown]
# ### Save PhiTilList

# %%
PhiTilName = 'Phi_R' + str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(1e-8)) + '_Vib_step='+ str(Vib_step).replace('.','pt')+ '_Vib_start=' +str(Vib_start).replace('.','pt') +'_Vib_stop='+ str(Vib_stop).replace('.','pt') +  '_Vmb'+ str(int(Vmb*300))+ '_Vob'+ str(int(Vob*300)) +'.npy'
fileName = "phiFiles/Vib_sweep/" + str(PhiTilName)

phitilNump = cp.asnumpy(phitilList)
np.save(fileName, phitilNump)

# Eztil = np.zeros(N+1)
# Phitil = np.zeros(N+1)
# Ertil = np.zeros(N)
# EztilTOP = np.zeros(N+1)
# EztilBOTTOM = np.zeros(N+1)

# %% [markdown]
# ## Load PhiTilList if already calculated

# %%
# in the filename, change the Vob step to the one you used in the phitilGen function
PhiTilName = 'Phi_R' + str(R).replace('.','pt') + '_H' + str(H).replace('.','pt') + '_N' + str(N) + '_M' + str(M) + '_posiE' + str(position_of_electrons) + '_epsE' + str(np.log10(1e-10)) + '_Vib_step='+ str(Vib_step).replace('.','pt')+ '_Vib_start=' +str(Vib_start).replace('.','pt') +'_Vib_stop='+ str(Vib_stop).replace('.','pt') +  '_Vmb'+ str(int(Vmb*300))+ '_Vob'+ str(int(Vob*300)) +'.npy'
fileName = "phiFiles/Vib_sweep/" + str(PhiTilName)
print(PhiTilName)
phitilNump=np.load(fileName)
print(np.shape(phitilNump))

Eztil = np.zeros(N+1)
Phitil = np.zeros(N+1)
Ertil = np.zeros(N)
EztilTOP = np.zeros(N+1)
EztilBOTTOM = np.zeros(N+1)
# Out:
# Phi_R0pt75_H0pt2_N500_M200_posiE100_epsE-10.0_Vib_step=0pt2_Vib_start=3_Vib_stop=30_Vmb-20_Vob-20.npy
# (135, 201, 501)

# %% [markdown]
# ## Saturated density profile

# %%
print(phitilNump.shape)
print(len(Vib))
# Out:
# (135, 201, 501)
# 135

# %%
#for each potential, calculates the density profile (depeding on the radus of the electron pool)
Ezbelow = np.zeros(N+1)
Ezabove = np.zeros(N+1)
print(len(phitilNump))    

N_total_list = np.zeros(len(phitilNump))
N_per_ring_list = np.zeros((len(phitilNump), N+1))
denList = np.zeros((len(phitilNump), N+1))
density_max_list = np.zeros(len(phitilNump))
R_star_list = np.zeros(len(phitilNump))
Ertil_list=np.zeros((len(phitilNump), N))
Eztil_list = np.zeros((len(phitilNump), N+1))

for l in range(0, len(phitilNump)):


    print("Iterations Left: " + str(len(phitilNump) - l + 1))

    # ------------ homogen. potential  ------------ #
    phitil = phitilNump[l]

        # ---------- homogen. electric z-field at the el. layer (CGS) ---------- #
    Eztil[:] = (phitil[position_of_electrons-1] - phitil[position_of_electrons])/hz
    
    Phitil = phitil[position_of_electrons]
    
    # --------- homogen. electric r-field at the el. layer (CGS) ------------ #
    Ertil[0:N]=(phitil[position_of_electrons,0:N]-phitil[position_of_electrons,1:N+1])/hr

    # --------- homogen. electric z-field at the cell's top (CGS) ---------- #
    EztilTOP[:] = (phitil[M-1, :]-phitil[M,:])/hz

    # --------- homogen. electric z-field at the cell's bottom (CGS) ---------- #
    EztilBOTTOM[:] = (phitil[0, :] - phitil[1,:])/hz


    radius_of_electron_pool = np.round(0.4/hr)
    
    radius_of_electron_pool_list = np.arange(0,radius_of_electron_pool+1)

    Ezuplist = np.zeros(len(radius_of_electron_pool_list))

    G_at_electrons = np.copy(G[position_of_electrons])
    G_below_electrons = np.copy(G[position_of_electrons-1])
    G_above_electrons = np.copy(G[position_of_electrons+1])

    
    for k in range(0, len(radius_of_electron_pool_list)):

    

        radius_of_electron_pool = radius_of_electron_pool_list[k]
        density, N_total, A, N_per_ring = distribSTATIC(R,H,N,M,G,Ertil, dGr,radius_of_electron_pool)
        

        # ------------- induced charge at the top inner electrode ------------------- #
        Ez = EztilTOP[0:N]
        Qsum = np.add.reduce(Ez[0:int(N_Vit)] * A[0:int(N_Vit)]/(4 * np.pi))
        N_ind=Qsum/e

        # ------------- induced charge at the bottom inner electrode ------------------- #
        Ez = EztilBOTTOM[0:N]
        Qsum = np.add.reduce(Ez[0:int(N_Vit)] * A[0:int(N_Vit)]/(4 * np.pi))
        N_ind = Qsum/e
        
        # ------------  potential at/below/above the electrons ------------ #


        copyAr2D(G_at_electrons, G[position_of_electrons].T)
        copyAr2D(G_below_electrons, G[position_of_electrons-1].T)
        copyAr2D(G_above_electrons, G[position_of_electrons+1].T)
        
        phi_at_electrons = phitil[position_of_electrons] - 4 * np.pi * e * hr * np.dot(density, G_at_electrons)
        phi_below_electrons = phitil[position_of_electrons-1] - 4 * np.pi * e * hr * np.dot(density, G_below_electrons)
        phi_above_electrons = phitil[position_of_electrons+1] - 4 * np.pi * e * hr * np.dot(density, G_above_electrons)

        # ---------- electric r-field across the liquid surface  ---------- #
        Er = np.zeros(N)

        Er[0:N] = (phi_at_electrons[0:N] - phi_at_electrons[1:N+1])/hr
        
        # ------------ electric field acting on electrons  ---------------- #
        Ezbelow[0:N+1] = (phi_below_electrons[0:N+1] - phi_at_electrons[0:N+1])/hz
        Ezabove[0:N+1] = (phi_at_electrons[0:N+1] - phi_above_electrons[0:N+1])/hz
        
        # adds the electric field acting on the electrons at the center to a list 
        Ezuplist[k] = Ezabove[0]
    
    
    minimum = np.amin(np.abs(Ezuplist))
    # chooses the index of the smallest absolute value of the electric field acting on the electrons at the center
    idx = np.argmin(np.abs(Ezuplist))

    # chooses the radius of the electron pool accordingly
    radius_of_electron_pool = radius_of_electron_pool_list[idx]

    #calculates the final density profile with the chosen radius of the electron pool
    # this is done for every potential in the Vob sweep
    density, N_total, A, N_per_ring = distribSTATIC(R,H,N,M,G,Ertil, dGr,radius_of_electron_pool)
    
    # check eq 56 
    print(np.max(np.abs(np.dot(density[:int(radius_of_electron_pool)+1], dGr[:int(radius_of_electron_pool)+1, :int(radius_of_electron_pool)+1]) -Ertil[:int(radius_of_electron_pool)+1])))
    
    N_total_list[l] = N_total
    print(N_total*1e-7)
    denList[l] = density
    density_max = np.amax(np.abs(density))
    density_max_list[l] = density_max
    R_star = np.sqrt(N_total/(density_max * np.pi))
    R_star_list[l] = R_star
    N_per_ring_list[l] = N_per_ring
    Ertil_list[l]=Ertil
    Eztil_list[l] = Eztil

colors = plt.cm.jet(np.linspace(0,1,len(denList)))

print(N_total_list)
# Out:
# 135
# Iterations Left: 136
# 2.7755575615628914e-17
# 0.28326324294166716
# Iterations Left: 135
# 2.6020852139652106e-17
# 0.3053021233431622
# Iterations Left: 134
# 3.0357660829594124e-17
# 0.3398944519892123
# Iterations Left: 133
# 3.469446951953614e-17
# 0.3659925207004977
# Iterations Left: 132
# 4.85722573273506e-17
# 0.39393960339392736
# Iterations Left: 131
# 3.469446951953614e-17
# 0.4238538501640072
# Iterations Left: 130
# 4.163336342344337e-17
# 0.4558595302256543
# Iterations Left: 129
# 4.85722573273506e-17
# 0.4900871201373021
# Iterations Left: 128
# 4.163336342344337e-17
# 0.5266733902497005
# Iterations Left: 127
# 4.597017211338539e-17
# 0.5657614019732893
# Iterations Left: 126
# 5.204170427930421e-17
# 0.5886710000240333
# Iterations Left: 125
# 3.642919299551295e-17
# 0.6319481408651589
# Iterations Left: 124
# 6.938893903907228e-17
# 0.6572786700002001
# Iterations Left: 123
# 5.551115123125783e-17
# 0.7051290779334394
# Iterations Left: 122
# 5.0306980803327406e-17
# 0.733098978019582
# Iterations Left: 121
# 4.5102810375396984e-17
# 0.7620595497906982
# Iterations Left: 120
# 5.551115123125783e-17
# 0.792040275638161
# Iterations Left: 119
# 6.938893903907228e-17
# 0.848684594252032
# Iterations Left: 118
# 5.551115123125783e-17
# 0.8817061871229439
# Iterations Left: 117
# 6.245004513516506e-17
# 0.9158653697960788
# Iterations Left: 116
# 9.020562075079397e-17
# 0.9511939307466953
# Iterations Left: 115
# 6.331740687315346e-17
# 0.9877240730723162
# Iterations Left: 114
# 6.938893903907228e-17
# 1.0254883769542626
# Iterations Left: 113
# 8.326672684688674e-17
# 1.0645197433950044
# Iterations Left: 112
# 2.9387554541383394
# Iterations Left: 67
# 1.942890293094024e-16
# 2.954952044620431
# Iterations Left: 66
# 1.6132928326584306e-16
# 3.048434720954689
# Iterations Left: 65
# 2.1337098754514727e-16
# 3.0650532567136803
# Iterations Left: 64
# 1.8041124150158794e-16
# 3.0816717646781826
# Iterations Left: 63
# 1.457167719820518e-16
# 3.178170127752885
# Iterations Left: 62
# 1.6306400674181987e-16
# 3.1952177692658084
# Iterations Left: 61
# 1.6653345369377348e-16
# 3.212265391458818
# Iterations Left: 60
# 1.942890293094024e-16
# 3.3118090436424232
# Iterations Left: 59
# 2.636779683484747e-16
# 3.3292928899650645
# Iterations Left: 58
# 1.8041124150158794e-16
# 3.346776717609806
# Iterations Left: 57
# 2.2898349882893854e-16
# 3.4493911632005103
# Iterations Left: 56
# 1.8041124150158794e-16
# 3.4673181752897366
# Iterations Left: 55
# 2.0816681711721685e-16
# 3.485245171251325
# Iterations Left: 54
# 1.942890293094024e-16
# 3.5909514937201283
# Iterations Left: 53
# 1.6653345369377348e-16
# 3.6093284995494566
# Iterations Left: 52
# 2.498001805406602e-16
# 3.6277054929535253
# Iterations Left: 51
# 2.220446049250313e-16
# 3.736520061984187
# Iterations Left: 50
# 2.3592239273284576e-16
# 3.755353739193422
# Iterations Left: 49
# 2.1337098754514727e-16
# 3.7741874112835285
# Iterations Left: 48
# 2.6194324487249787e-16
# 3.8861216247891597
# Iterations Left: 47
# 2.0816681711721685e-16
# 3.9054184804510084
# Iterations Left: 46
# 2.3592239273284576e-16
# 3.9247153261189327
# Iterations Left: 45
# 1.942890293094024e-16
# 3.9440121618994324
# Iterations Left: 44
# 2.220446049250313e-16
# 4.059541677152519
# Iterations Left: 43
# 2.42861286636753e-16
# 4.079308010912023
# Iterations Left: 42
# 2.2898349882893854e-16
# 4.09907434682077
# Iterations Left: 41
# 1.942890293094024e-16
# 4.118840673048184
# Iterations Left: 40
# 1.942890293094024e-16
# 4.237978321456795
# Iterations Left: 39
# 2.498001805406602e-16
# 4.258220255277927
# Iterations Left: 38
# 3.191891195797325e-16
# 4.2784621912949365
# Iterations Left: 37
# 2.914335439641036e-16
# 4.298704112882857
# Iterations Left: 36
# 2.7755575615628914e-16
# 4.421456311971551
# Iterations Left: 35
# 2.220446049250313e-16
# 4.442179733481842
# Iterations Left: 34
# 2.42861286636753e-16
# 4.462903157232442
# Iterations Left: 33
# 2.498001805406602e-16
# 4.483626571642196
# Iterations Left: 32
# 2.7755575615628914e-16
# 4.609992980199796
# Iterations Left: 31
# 1.9081958235744878e-16
# 4.631203548859003
# Iterations Left: 30
# 2.498001805406602e-16
# 4.652414113123945
# Iterations Left: 29
# 2.8102520310824275e-16
# 4.673624669826355
# Iterations Left: 28
# 2.220446049250313e-16
# 4.803597934153412
# Iterations Left: 27
# 2.1684043449710089e-16
# 4.825301035691044
# Iterations Left: 26
# 2.7755575615628914e-16
# 4.847004126356822
# Iterations Left: 25
# 2.498001805406602e-16
# 4.868707220884849
# Iterations Left: 24
# 3.209238430557093e-16
# 5.00227269586558
# Iterations Left: 23
#  42379783.21456796 42582202.55277927 42784621.91294937 42987041.12882857
#  44214563.11971551 44421797.33481842 44629031.57232442 44836265.71642196
#  46099929.80199796 46312035.48859003 46524141.13123945 46736246.69826355
#  48035979.34153412 48253010.35691044 48470041.26356822 48687072.20884849
#  50022726.9586558  50244734.49853829 50466741.96306039 50688749.38455933
#  50910756.7631566  52287136.83510248 52514169.13833418 52741201.3501233
#  52968233.51899895 53195265.66096696 54612162.33294225 54844264.50358309
#  55076366.69490305 55308468.79524463 55540570.91593846 56997686.4671803
#  57234900.54241449 57472114.63756962 57709328.64160126 57946542.66526943
#  59443488.54833569 59685853.05233817 59928217.5127593 ]

# %%
fig, ax = plt.subplots(1,1,figsize=(5, 5), sharex=True)

for d in range(len(phitilNump)):
    ax.plot(np.arange(0, len(denList[d])) * hr,denList[d], color = colors[d], label = str(np.round(Vib[d] * 300,1))+'V')



ax.legend(ncol=np.ceil(len(denList)/20), bbox_to_anchor=(1.15, 1.05))
ax.set_ylabel(r"Density $[cm^{-2}]$")
# ax2.set_ylabel(r"$\tilde{E^r}$ [statV/cm]")
# ax2.set_ylabel(r"$\tilde{E^z}$ [statV/cm]")
ax.set_xlabel("Radius [cm]")
# ax2.set_xlabel("Radius [cm]")
plt.show()

# %% [markdown]
# ### Run if you want to save the saturated densities

# %%
for idx in range(len(denList)):
    Vib_str = f"{Vib[idx] * 300:.1f}".replace(".", "p")
    # filename = f"DensityFiles/Saturated_density/saturated_density_Vib{int(Vib*300)}_Vmb{int(Vmb*300)}_Vob{Vob_str}_N{N}_M{M}_posiE{position_of_electrons}.npy"
    filename = f"DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib{Vib_str}_Vob{int(Vob*300)}_Vmb{int(Vmb*300)}_N{N}_M{M}_posiE{position_of_electrons}.npy"
    print(filename)
    radius = np.arange(0, len(denList[d])) * hr
    data_to_save = np.array([radius, denList[idx]])
    np.save(filename, data_to_save)
# Out:
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib3p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib3p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib3p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib3p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib3p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib4p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib4p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib4p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib4p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib4p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib5p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib5p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib5p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib5p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib5p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib6p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib6p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib6p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib6p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib6p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib7p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib7p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib7p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib7p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib7p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib8p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib8p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib8p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib8p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib8p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib9p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib9p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib9p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib9p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib9p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib10p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib10p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib10p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib10p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib10p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib11p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib11p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib11p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib11p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib11p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib12p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib12p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib12p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib12p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib12p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib13p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib13p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib13p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib13p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib13p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib14p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib14p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib14p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib14p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib14p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib15p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib15p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib15p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib15p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib15p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib16p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib16p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib16p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib16p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib16p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib17p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib17p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib17p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib17p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib17p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib18p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib18p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib18p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib18p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib18p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib19p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib19p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib19p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib19p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib19p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib20p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib20p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib20p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib20p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib20p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib21p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib21p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib21p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib21p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib21p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib22p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib22p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib22p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib22p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib22p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib23p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib23p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib23p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib23p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib23p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib24p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib24p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib24p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib24p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib24p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib25p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib25p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib25p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib25p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib25p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib26p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib26p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib26p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib26p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib26p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib27p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib27p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib27p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib27p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib27p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib28p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib28p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib28p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib28p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib28p8_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib29p0_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib29p2_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib29p4_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib29p6_Vob-20_Vmb-20_N500_M200_posiE100.npy
# DensityFiles/Vib_sweep_good/-20V/saturated_density_Vib29p8_Vob-20_Vmb-20_N500_M200_posiE100.npy

# %% [markdown]
# ## Fixed N Density List

# %%
Eztil = np.zeros(N+1)
Phitil = np.zeros(N+1)
Ertil = np.zeros(N)
EztilTOP = np.zeros(N+1)
EztilBOTTOM = np.zeros(N+1)

Ezbelow = np.zeros(N+1)
Ezabove = np.zeros(N+1)

N_Fixed_list = np.copy(N_total_list)

# fix the number of electrons to be equal to the number of electrons at Vob=-96V 
# indeed the sweep of Vob is done from -96V to -5.5V, so the number of electrons at Vob=-96V is the one that is fixed



N_Fixed = N_total_list[0]

for l in range(0, len(phitilNump)):
    print("Iterations Left: " + str(len(phitilNump) - l + 1))

    # ------------ homogen. potential  ------------ #
    phitil = phitilNump[l]



        # ---------- homogen. electric z-field at the el. layer (CGS) ---------- #
    Eztil[:] = (phitil[position_of_electrons-1] - phitil[position_of_electrons])/hz
    
    Phitil = phitil[position_of_electrons]
    
    # --------- homogen. electric r-field at the el. layer (CGS) ------------ #
    Ertil[0:N]=(phitil[position_of_electrons,0:N]-phitil[position_of_electrons,1:N+1])/hr

    # --------- homogen. electric z-field at the cell's top (CGS) ---------- #
    EztilTOP[:] = (phitil[M-1, :]-phitil[M,:])/hz

    # --------- homogen. electric z-field at the cell's bottom (CGS) ---------- #
    EztilBOTTOM[:] = (phitil[0, :] - phitil[1,:])/hz

    
    radius_of_electron_pool = np.round(0.4/hr)
    print(radius_of_electron_pool)
    
    #radius_of_electron_pool_list = np.arange(radius_of_electron_pool - 350,radius_of_electron_pool+1)
    radius_of_electron_pool_list = np.arange(0,radius_of_electron_pool+1)

    Ezuplist = np.zeros(len(radius_of_electron_pool_list))

    G_at_electrons = np.copy(G[position_of_electrons])
    G_below_electrons = np.copy(G[position_of_electrons-1])
    G_above_electrons = np.copy(G[position_of_electrons+1])


    N_total_vect = np.zeros(len(radius_of_electron_pool_list))
    for k in range(0, len(radius_of_electron_pool_list)):
        radius_of_electron_pool = radius_of_electron_pool_list[k]
        density, N_total, A, N_per_ring = distribSTATIC(R,H,N,M,G,Ertil, dGr,radius_of_electron_pool)
        N_total_vect[k] = N_total
    minimum = np.amin(np.abs(N_total_vect - N_Fixed))
    idx = np.argmin(np.abs(N_total_vect - N_Fixed))    

    
    radius_of_electron_pool = radius_of_electron_pool_list[idx]

    
    density, N_total, A, N_per_ring = distribSTATIC(R,H,N,M,G,Ertil, dGr,radius_of_electron_pool)

    
    N_total_list[l] = N_total
    denList[l] = density
    density_max = np.amax(np.abs(density))
    density_max_list[l] = density_max
    R_star = np.sqrt(N_total/(density_max * np.pi))
    R_star_list[l] = R_star
    print((N_total-N_Fixed)/N_Fixed)
# Out:
# Iterations Left: 211
# 267.0
# 0.0
# Iterations Left: 210
# 267.0
# -0.004402862500283465
# Iterations Left: 209
# 267.0
# -0.008805627556208256
# Iterations Left: 208
# 267.0
# -0.013208539699117327
# Iterations Left: 207
# 267.0
# 0.012184895553067517
# Iterations Left: 206
# 267.0
# 0.007649496122009492
# Iterations Left: 205
# 267.0
# 0.0031132089617886037
# Iterations Left: 204
# 267.0
# -0.001422675451048577
# Iterations Left: 203
# 267.0
# -0.00595858660410789
# Iterations Left: 202
# 267.0
# -0.010495082191339357
# Iterations Left: 201
# 267.0
# 0.014747670603670101
# Iterations Left: 200
# 267.0
# 0.01007515916478573
# Iterations Left: 199
# 267.0
# 0.005402738898982935
# Iterations Left: 198
# 267.0
# 0.0007291455121932624
# Iterations Left: 197
# 267.0
# -0.00394390939688195
# Iterations Left: 196
# 267.0
# -0.008616995613977786
# Iterations Left: 195
# 267.0
# -0.013290571399773639
# Iterations Left: 194
# 267.0
# 0.011632086440639781
# Iterations Left: 193
# 267.0
# 0.006818779856731922
# Iterations Left: 192
# 267.0
# 0.00200496765672544
# Iterations Left: 191
# 267.0
# -0.0028088819541302176
# Iterations Left: 190
# 267.0
# -0.007623245024582653
# Iterations Left: 189
# 267.0
# -0.012437169873994682
# Iterations Left: 188
# 267.0
# 0.012269260718783983
# Iterations Left: 187
# 267.0
# 0.00731146244556923
# Iterations Left: 186
# 267.0
# 0.0023537402307990418
# Iterations Left: 185
# 267.0
# -0.0026046317059975456
# Iterations Left: 184
# 267.0
# -0.00756304633338969
# Iterations Left: 183
# 267.0
# -0.012522116870948993
# Iterations Left: 182
# 267.0
# 0.011935710895881888
# Iterations Left: 181
# 267.0
# 0.006829112180104131
# Iterations Left: 180
# 267.0
# 0.0017229781607060644
# Iterations Left: 179
# 267.0
# -0.0033837181537316164
# Iterations Left: 178
# 267.0
# -0.008490463457670632
# Iterations Left: 177
# 267.0
# -0.013597256987750984
# Iterations Left: 176
# 267.0
# 0.010577030666585654
# Iterations Left: 175
# 267.0
# 0.005318783576282088
# Iterations Left: 174
# 267.0
# 5.994599198566881e-05
# Iterations Left: 173
# 267.0
# -0.005198297564722682
# Iterations Left: 172
# 267.0
# -0.010457245214599122
# Iterations Left: 171
# 267.0
# 0.013551785708200577
# Iterations Left: 170
# 267.0
# 0.008138155120285203
# Iterations Left: 169
# 267.0
# 0.0027232407513205184
# Iterations Left: 168
# 267.0
# -0.0026911743440772287
# Iterations Left: 167
# 267.0
# -0.008105541624945003
# Iterations Left: 166
# 267.0
# -0.013521316593401271
# Iterations Left: 165
# 267.0
# 0.010136025303995462
# Iterations Left: 164
# 267.0
# 0.004561612785274359
# Iterations Left: 163
# 267.0
# -0.0010127634688037817
# Iterations Left: 162
# 267.0
# -0.006587900278150111
# Iterations Left: 161
# 267.0
# -0.012163108430524058
# Iterations Left: 160
# 267.0
# 0.011265996537858211
# Iterations Left: 159
# 267.0
# 0.010596453726911991
# Iterations Left: 48
# 267.0
# -0.0037969349666804966
# Iterations Left: 47
# 267.0
# 0.005867909852413065
# Iterations Left: 46
# 267.0
# -0.00884144541533419
# Iterations Left: 45
# 267.0
# 0.0002597864993736499
# Iterations Left: 44
# 267.0
# 0.009101394650384663
# Iterations Left: 43
# 267.0
# -0.00624614072525729
# Iterations Left: 42
# 267.0
# 0.0020055290948191706
# Iterations Left: 41
# 267.0
# 0.009980313874086606
# Iterations Left: 40
# 267.0
# -0.006015311556131334
# Iterations Left: 39
# 267.0
# 0.001348331950865681
# Iterations Left: 38
# 267.0
# 0.008417217776476128
# Iterations Left: 37
# 267.0
# -0.008230770443695353
# Iterations Left: 36
# 267.0
# -0.0017882747158389624
# Iterations Left: 35
# 267.0
# 0.004349933950746018
# Iterations Left: 34
# 267.0
# 0.010180630527561378
# Iterations Left: 33
# 267.0
# -0.007453868451941849
# Iterations Left: 32
# 267.0
# -0.002261831701748199
# Iterations Left: 31
# 267.0
# 0.0026200211932521423
# Iterations Left: 30
# 267.0
# 0.0071917630589550426
# Iterations Left: 29
# 267.0
# -0.011428222309224434
# Iterations Left: 28
# 267.0
# -0.007490333961177526
# Iterations Left: 27
# 267.0
# -0.003855618516400693
# Iterations Left: 26
# 267.0
# -0.0005173558167615405
# Iterations Left: 25
# 267.0
# 0.002530182890903869
# Iterations Left: 24
# 267.0
# 0.005296541888846377
# Iterations Left: 23
# 267.0
# 0.0077906761607665805
# Iterations Left: 22
# 267.0
# 0.010025831553824768
# Iterations Left: 21
# 267.0
# -0.010845088356718371
# Iterations Left: 20
# 267.0
# -0.009166898600055534
# Iterations Left: 19
# 267.0
# -0.007715761946795927
# Iterations Left: 18
# 267.0
# -0.006473276398640563
# Iterations Left: 17
# 267.0
# -0.005421358922457187
# Iterations Left: 16
# 267.0
# -0.004538572195197624
# Iterations Left: 15
# 267.0
# -0.003801046023722555
# Iterations Left: 14
# 267.0
# -0.026468557346976795
# Iterations Left: 13
# 267.0
# -0.04913622605886838
# Iterations Left: 12
# 267.0
# -0.07180405135696619
# Iterations Left: 11
# 267.0
# -0.09447203244269098
# Iterations Left: 10
# 267.0
# -0.11714016852123495
# Iterations Left: 9
# 267.0
# -0.13980845880155626
# Iterations Left: 8
# 267.0
# -0.1624769024964057
# Iterations Left: 7
# 267.0
# -0.1851459887754829
# Iterations Left: 6
# 267.0
# -0.20781473301465117
# Iterations Left: 5
# 267.0
# -0.23048362835162114
# Iterations Left: 4
# 267.0
# -0.253152674013894
# Iterations Left: 3
# 267.0
# -0.275821869232672
# Iterations Left: 2
# 267.0
# -0.29849190750383836

# %%
colors = plt.cm.jet(np.linspace(0,1,len(denList)))
for d in range(0, 195):
    plt.plot(np.arange(0, len(denList[d])) * hr,denList[d], color = colors[d], label = str(Vmb[d] * 300)+'V')

plt.ylabel("Density")
plt.xlabel("Radius")
# plt.legend(ncol=np.ceil(len(denList)/20), bbox_to_anchor=(1.15, 1.05))
plt.title(f'Density profile for different Vmb potentials ($\epsilon={eps} ,N={N}, M={M}$)')
plt.show()


plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\e'
# <>:8: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\riken\AppData\Local\Temp\ipykernel_20796\1919660459.py:8: SyntaxWarning: invalid escape sequence '\e'
#   plt.title(f'Density profile for different Vmb potentials ($\epsilon={eps} ,N={N}, M={M}$)')

# %%
#the file DensityFiles/EPS{int(np.log10(eps))} needs to be created before running the code
for idx in range(len(denList)):
    Vib_str = f"{Vib[idx] * 300:.1f}".replace(".", "p")
    # filename = f"DensityFiles/Saturated_density/saturated_density_Vib{int(Vib*300)}_Vmb{int(Vmb*300)}_Vob{Vob_str}_N{N}_M{M}_posiE{position_of_electrons}.npy"
    filename = f"DensityFiles/Vib_sweep_good/-15V/FixedN_Vib{Vib_str}_Vob{int(Vob*300)}_Vmb{int(Vmb*300)}_N{N}_M{M}_posiE{position_of_electrons}.npy"
    # filename = f"DensityFiles/EPS{int(np.log10(eps))}/FixedN_Vib{int(Vib*300)}_Vmb{int(Vmb*300)}_Vob{Vob_str}_N{N}_M{M}_posiE{position_of_electrons}.npy"
    print(filename)
    radius = np.arange(0, len(denList[d])) * hr
    data_to_save = np.array([radius, denList[idx]])
    np.save(filename, data_to_save)
# Out:
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-32p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-31p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-31p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-31p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-31p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-31p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-30p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-30p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-30p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-30p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-30p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-29p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-29p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-29p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-29p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-29p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-28p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-28p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-28p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-28p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-28p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-27p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-27p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-27p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-27p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-27p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-26p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-26p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-26p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-26p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-26p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-25p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-25p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-25p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-25p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-25p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-24p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-24p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-24p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-24p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-24p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-23p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-23p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-23p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-23p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-23p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-22p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-22p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-22p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-22p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-22p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-21p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-21p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-21p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-21p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-21p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-20p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-20p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-20p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-20p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-20p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-19p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-19p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-19p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-19p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-19p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-18p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-18p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-18p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-18p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-18p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-17p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-17p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-17p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-17p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-17p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-16p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-16p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-16p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-16p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-16p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-15p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-15p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-15p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-15p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-15p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-14p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-14p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-14p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-14p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-14p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-13p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-13p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-13p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-13p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-13p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-12p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-12p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-12p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-12p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-12p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-11p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-11p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-11p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-11p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-11p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-10p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-10p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-10p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-10p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-10p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-9p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-9p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-9p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-9p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-9p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-8p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-8p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-8p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-8p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-8p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-7p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-7p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-7p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-7p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-7p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-6p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-6p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-6p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-6p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-6p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-5p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-5p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-5p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-5p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-5p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-4p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-4p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-4p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-4p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-4p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-3p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-3p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-3p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-3p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-3p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-2p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-2p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-2p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-2p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-2p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-1p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-1p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-1p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-1p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-1p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-0p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-0p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-0p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb-0p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb0p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb0p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb0p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb0p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb0p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb1p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb1p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb1p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb1p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb1p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb2p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb2p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb2p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb2p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb2p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb3p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb3p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb3p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb3p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb3p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb4p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb4p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb4p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb4p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb4p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb5p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb5p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb5p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb5p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb5p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb6p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb6p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb6p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb6p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb6p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb7p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb7p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb7p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb7p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb7p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb8p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb8p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb8p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb8p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb8p8_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb9p0_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb9p2_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb9p4_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb9p6_N500_M200_posiE100.npy
# DensityFiles/Vmb_sweep2/FixedN_Vib10_Vob-32_Vmb9p8_N500_M200_posiE100.npy
